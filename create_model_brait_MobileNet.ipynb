# %%
import os
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import seaborn as sns

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\a')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\b')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\c')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\d')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\e')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\f')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\g')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\h')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\i')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\j')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\k')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\l')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\m')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\n')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\o')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\p')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\q')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\r')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\s')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\t')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\u')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\v')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\w')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\x')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\y')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\z')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\colon')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\koma')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\petik_satu')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\semicolon')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\space')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\tanda_hubung')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\tanda_seru')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\tanda_tanya')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
folder_path = (r'D:\BRAIT\Braille Dataset\train\titik')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
image_dir = Path(r'D:\BRAIT\Braille Dataset\train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(2)
# Out:
#                                           Filepath Label
# 0  D:\BRAIT\Braille Dataset\train\t\t1.JPG9whs.jpg     t
# 1  D:\BRAIT\Braille Dataset\train\m\m1.JPG4whs.jpg     m

# %%
# Display some pictures of the dataset with their labels

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
#Shuffle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Separate in train and test data
train_df, validasi_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %% [markdown]
# create model

# %%
from keras import Model, Input
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from keras import layers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
import numpy as np
# %matplotlib inline
# Out:
# WARNING:tensorflow:From C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
input_shape = (180,180,3)
model_input = Input(shape=input_shape)

mobileNet = MobileNetV2(input_shape=input_shape, 
                        input_tensor=model_input, 
                        include_top=False, 
                        weights="imagenet")

for layer in mobileNet.layers:
    layer.trainable = False
# Out:
# WARNING:tensorflow:From C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:From C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    shear_range=10,
    fill_mode='nearest',
    validation_split=0.2,
    horizontal_flip=False)

val_datagen = ImageDataGenerator(rescale=1./255)
                                   
train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         seed=0,
                                         target_size=(180,180),
                                         batch_size=16,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                        subset='training',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=validasi_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         seed=0,
                                         target_size=(180,180),
                                         batch_size=16,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# Out:
# Found 2081 validated image filenames belonging to 35 classes.
# Found 651 validated image filenames belonging to 35 classes.

# %%
x_mobileNet = mobileNet.output
# Flatten 
x_mobileNet = Flatten()(x_mobileNet)
# Add a fully connected layer with 512 hidden units and ReLU activation
x_mobileNet = Dense(512, activation='relu')(x_mobileNet)
# Add a dropout rate of 0.5
x_mobileNet = Dropout(0.5)(x_mobileNet)
# Add a final softmax layer for classification
x_mobileNet = Dense(35, activation='softmax')(x_mobileNet)

# Configure and compile the model
mobileNet_model = Model(model_input, x_mobileNet)
optimizer = Adam(learning_rate=1e-5)
mobileNet_model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint('MobileNet_Braille_model_best.h5',
                                      save_best_only=True,
                                      monitor='val_loss',
                                      mode='min', verbose=1)

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.1 and logs.get('val_loss') < 0.1):
      print("\Stopped, Accuracy up to 98%")
      self.model.stop_training = True;

# %%
callbacks = myCallback()

# Fit the model
history_mobileNet = mobileNet_model.fit(
    train_data,
    validation_data=validasi_data,
    steps_per_epoch=train_data.n//16,
    validation_steps=validasi_data.n//16,
    epochs=50,
    callbacks=[callbacks, checkpoint_callback])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 130/130 [==============================] - ETA: 0s - loss: 3.7858 - accuracy: 0.1366
# Epoch 1: val_loss improved from inf to 2.70070, saving model to MobileNet_Braille_model_best.h5
# C:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 130/130 [==============================] - 76s 556ms/step - loss: 3.7858 - accuracy: 0.1366 - val_loss: 2.7007 - val_accuracy: 0.2734
# Epoch 2/50
# 130/130 [==============================] - ETA: 0s - loss: 2.5610 - accuracy: 0.3065
# Epoch 2: val_loss improved from 2.70070 to 2.18919, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 58s 449ms/step - loss: 2.5610 - accuracy: 0.3065 - val_loss: 2.1892 - val_accuracy: 0.4156
# Epoch 3/50
# 130/130 [==============================] - ETA: 0s - loss: 2.0474 - accuracy: 0.4460
# Epoch 3: val_loss improved from 2.18919 to 1.83767, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 60s 458ms/step - loss: 2.0474 - accuracy: 0.4460 - val_loss: 1.8377 - val_accuracy: 0.5266
# Epoch 4/50
# 130/130 [==============================] - ETA: 0s - loss: 1.6830 - accuracy: 0.5249
# Epoch 4: val_loss improved from 1.83767 to 1.56013, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 326s 3s/step - loss: 1.6830 - accuracy: 0.5249 - val_loss: 1.5601 - val_accuracy: 0.5859
# Epoch 5/50
# 130/130 [==============================] - ETA: 0s - loss: 1.4124 - accuracy: 0.6068
# Epoch 5: val_loss improved from 1.56013 to 1.37997, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 24s 188ms/step - loss: 1.4124 - accuracy: 0.6068 - val_loss: 1.3800 - val_accuracy: 0.6422
# Epoch 6/50
# 130/130 [==============================] - ETA: 0s - loss: 1.1707 - accuracy: 0.6688
# Epoch 6: val_loss improved from 1.37997 to 1.27928, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 30s 229ms/step - loss: 1.1707 - accuracy: 0.6688 - val_loss: 1.2793 - val_accuracy: 0.6578
# Epoch 7/50
# 130/130 [==============================] - ETA: 0s - loss: 1.0435 - accuracy: 0.7090
# Epoch 7: val_loss improved from 1.27928 to 1.15368, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 34s 264ms/step - loss: 1.0435 - accuracy: 0.7090 - val_loss: 1.1537 - val_accuracy: 0.7000
# Epoch 8/50
# 130/130 [==============================] - ETA: 0s - loss: 0.8977 - accuracy: 0.7482
# Epoch 8: val_loss improved from 1.15368 to 1.08384, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 37s 288ms/step - loss: 0.8977 - accuracy: 0.7482 - val_loss: 1.0838 - val_accuracy: 0.7016
# Epoch 9/50
# 130/130 [==============================] - ETA: 0s - loss: 0.7902 - accuracy: 0.7734
# Epoch 9: val_loss improved from 1.08384 to 1.05255, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 59s 457ms/step - loss: 0.7902 - accuracy: 0.7734 - val_loss: 1.0525 - val_accuracy: 0.7203
# Epoch 10/50
# 130/130 [==============================] - ETA: 0s - loss: 0.7417 - accuracy: 0.7918
# Epoch 10: val_loss improved from 1.05255 to 1.00075, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 54s 417ms/step - loss: 0.7417 - accuracy: 0.7918 - val_loss: 1.0007 - val_accuracy: 0.7219
# Epoch 11/50
# 130/130 [==============================] - ETA: 0s - loss: 0.6970 - accuracy: 0.8019
# Epoch 11: val_loss improved from 1.00075 to 0.95449, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 72s 552ms/step - loss: 0.6970 - accuracy: 0.8019 - val_loss: 0.9545 - val_accuracy: 0.7391
# Epoch 12/50
# 130/130 [==============================] - ETA: 0s - loss: 0.6099 - accuracy: 0.8295
# Epoch 12: val_loss improved from 0.95449 to 0.91255, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 59s 457ms/step - loss: 0.6099 - accuracy: 0.8295 - val_loss: 0.9126 - val_accuracy: 0.7391
# Epoch 13/50
# 130/130 [==============================] - ETA: 0s - loss: 0.5373 - accuracy: 0.8513
# Epoch 13: val_loss improved from 0.91255 to 0.85509, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 58s 450ms/step - loss: 0.5373 - accuracy: 0.8513 - val_loss: 0.8551 - val_accuracy: 0.7891
# Epoch 14/50
# 130/130 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.8518
# Epoch 14: val_loss improved from 0.85509 to 0.82203, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 58s 446ms/step - loss: 0.5257 - accuracy: 0.8518 - val_loss: 0.8220 - val_accuracy: 0.7859
# Epoch 15/50
# 130/130 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.8581
# Epoch 15: val_loss did not improve from 0.82203
# 130/130 [==============================] - 57s 435ms/step - loss: 0.4851 - accuracy: 0.8581 - val_loss: 0.8226 - val_accuracy: 0.8031
# Epoch 16/50
# 130/130 [==============================] - ETA: 0s - loss: 0.4244 - accuracy: 0.8780
# Epoch 16: val_loss improved from 0.82203 to 0.81169, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 61s 467ms/step - loss: 0.4244 - accuracy: 0.8780 - val_loss: 0.8117 - val_accuracy: 0.7750
# Epoch 17/50
# 130/130 [==============================] - ETA: 0s - loss: 0.4098 - accuracy: 0.8872
# Epoch 17: val_loss improved from 0.81169 to 0.76412, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 57s 438ms/step - loss: 0.4098 - accuracy: 0.8872 - val_loss: 0.7641 - val_accuracy: 0.7937
# Epoch 18/50
# 130/130 [==============================] - ETA: 0s - loss: 0.3632 - accuracy: 0.8988
# Epoch 18: val_loss improved from 0.76412 to 0.72394, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 59s 456ms/step - loss: 0.3632 - accuracy: 0.8988 - val_loss: 0.7239 - val_accuracy: 0.8062
# Epoch 19/50
# 130/130 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.9123
# Epoch 19: val_loss did not improve from 0.72394
# 130/130 [==============================] - 55s 425ms/step - loss: 0.3384 - accuracy: 0.9123 - val_loss: 0.7511 - val_accuracy: 0.8000
# Epoch 20/50
# 130/130 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.9056
# Epoch 20: val_loss improved from 0.72394 to 0.69570, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 71s 546ms/step - loss: 0.3317 - accuracy: 0.9056 - val_loss: 0.6957 - val_accuracy: 0.8188
# Epoch 21/50
# 130/130 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.9177
# Epoch 21: val_loss did not improve from 0.69570
# 130/130 [==============================] - 74s 568ms/step - loss: 0.2964 - accuracy: 0.9177 - val_loss: 0.7092 - val_accuracy: 0.8156
# Epoch 22/50
# 130/130 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9090
# Epoch 22: val_loss improved from 0.69570 to 0.68782, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 74s 566ms/step - loss: 0.3005 - accuracy: 0.9090 - val_loss: 0.6878 - val_accuracy: 0.8234
# Epoch 23/50
# 130/130 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.9245
# Epoch 23: val_loss improved from 0.68782 to 0.67474, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 74s 568ms/step - loss: 0.2679 - accuracy: 0.9245 - val_loss: 0.6747 - val_accuracy: 0.8313
# Epoch 24/50
# 130/130 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.9332
# Epoch 24: val_loss did not improve from 0.67474
# 130/130 [==============================] - 72s 549ms/step - loss: 0.2550 - accuracy: 0.9332 - val_loss: 0.6824 - val_accuracy: 0.8172
# Epoch 25/50
# 130/130 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.9380
# Epoch 25: val_loss improved from 0.67474 to 0.67057, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 74s 566ms/step - loss: 0.2303 - accuracy: 0.9380 - val_loss: 0.6706 - val_accuracy: 0.8313
# Epoch 26/50
# 130/130 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9337
# Epoch 26: val_loss improved from 0.67057 to 0.63901, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 73s 561ms/step - loss: 0.2372 - accuracy: 0.9337 - val_loss: 0.6390 - val_accuracy: 0.8234
# Epoch 27/50
# 130/130 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9380
# Epoch 27: val_loss did not improve from 0.63901
# 130/130 [==============================] - 71s 548ms/step - loss: 0.2211 - accuracy: 0.9380 - val_loss: 0.6821 - val_accuracy: 0.8078
# Epoch 28/50
# 130/130 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.9322
# Epoch 28: val_loss improved from 0.63901 to 0.63831, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 73s 563ms/step - loss: 0.2205 - accuracy: 0.9322 - val_loss: 0.6383 - val_accuracy: 0.8328
# Epoch 29/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9443
# Epoch 29: val_loss improved from 0.63831 to 0.62898, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 74s 566ms/step - loss: 0.1941 - accuracy: 0.9443 - val_loss: 0.6290 - val_accuracy: 0.8281
# Epoch 30/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9448
# Epoch 30: val_loss did not improve from 0.62898
# 130/130 [==============================] - 71s 543ms/step - loss: 0.1904 - accuracy: 0.9448 - val_loss: 0.6575 - val_accuracy: 0.8062
# Epoch 31/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9496
# Epoch 31: val_loss did not improve from 0.62898
# 130/130 [==============================] - 72s 551ms/step - loss: 0.1784 - accuracy: 0.9496 - val_loss: 0.6736 - val_accuracy: 0.8000
# Epoch 32/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.9492
# Epoch 32: val_loss did not improve from 0.62898
# 130/130 [==============================] - 83s 634ms/step - loss: 0.1808 - accuracy: 0.9492 - val_loss: 0.6519 - val_accuracy: 0.8188
# Epoch 33/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9564
# Epoch 33: val_loss improved from 0.62898 to 0.60336, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 74s 567ms/step - loss: 0.1623 - accuracy: 0.9564 - val_loss: 0.6034 - val_accuracy: 0.8422
# Epoch 34/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9613
# Epoch 34: val_loss did not improve from 0.60336
# 130/130 [==============================] - 72s 554ms/step - loss: 0.1499 - accuracy: 0.9613 - val_loss: 0.6360 - val_accuracy: 0.8266
# Epoch 35/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9608
# Epoch 35: val_loss did not improve from 0.60336
# 130/130 [==============================] - 71s 545ms/step - loss: 0.1519 - accuracy: 0.9608 - val_loss: 0.6154 - val_accuracy: 0.8234
# Epoch 36/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9613
# Epoch 36: val_loss did not improve from 0.60336
# 130/130 [==============================] - 73s 561ms/step - loss: 0.1474 - accuracy: 0.9613 - val_loss: 0.6156 - val_accuracy: 0.8313
# Epoch 37/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9617
# Epoch 37: val_loss improved from 0.60336 to 0.59679, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 75s 573ms/step - loss: 0.1434 - accuracy: 0.9617 - val_loss: 0.5968 - val_accuracy: 0.8375
# Epoch 38/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9656
# Epoch 38: val_loss improved from 0.59679 to 0.58746, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 74s 566ms/step - loss: 0.1318 - accuracy: 0.9656 - val_loss: 0.5875 - val_accuracy: 0.8422
# Epoch 39/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9738
# Epoch 39: val_loss did not improve from 0.58746
# 130/130 [==============================] - 73s 563ms/step - loss: 0.1125 - accuracy: 0.9738 - val_loss: 0.6188 - val_accuracy: 0.8375
# Epoch 40/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9617
# Epoch 40: val_loss did not improve from 0.58746
# 130/130 [==============================] - 76s 586ms/step - loss: 0.1387 - accuracy: 0.9617 - val_loss: 0.6079 - val_accuracy: 0.8438
# Epoch 41/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9709
# Epoch 41: val_loss did not improve from 0.58746
# 130/130 [==============================] - 105s 805ms/step - loss: 0.1104 - accuracy: 0.9709 - val_loss: 0.6061 - val_accuracy: 0.8375
# Epoch 42/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9685
# Epoch 42: val_loss did not improve from 0.58746
# 130/130 [==============================] - 77s 595ms/step - loss: 0.1253 - accuracy: 0.9685 - val_loss: 0.6134 - val_accuracy: 0.8406
# Epoch 43/50
# 130/130 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9743
# Epoch 43: val_loss did not improve from 0.58746
# 130/130 [==============================] - 96s 741ms/step - loss: 0.1001 - accuracy: 0.9743 - val_loss: 0.6217 - val_accuracy: 0.8391
# Epoch 44/50
# 130/130 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9792
# Epoch 44: val_loss did not improve from 0.58746
# 130/130 [==============================] - 78s 598ms/step - loss: 0.0992 - accuracy: 0.9792 - val_loss: 0.6009 - val_accuracy: 0.8406
# Epoch 45/50
# 130/130 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9763
# Epoch 45: val_loss did not improve from 0.58746
# 130/130 [==============================] - 82s 629ms/step - loss: 0.0955 - accuracy: 0.9763 - val_loss: 0.5980 - val_accuracy: 0.8469
# Epoch 46/50
# 130/130 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9734
# Epoch 46: val_loss did not improve from 0.58746
# 130/130 [==============================] - 80s 614ms/step - loss: 0.0955 - accuracy: 0.9734 - val_loss: 0.6180 - val_accuracy: 0.8313
# Epoch 47/50
# 130/130 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9758
# Epoch 47: val_loss improved from 0.58746 to 0.58369, saving model to MobileNet_Braille_model_best.h5
# 130/130 [==============================] - 70s 535ms/step - loss: 0.0862 - accuracy: 0.9758 - val_loss: 0.5837 - val_accuracy: 0.8516
# Epoch 48/50
# 130/130 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9753
# Epoch 48: val_loss did not improve from 0.58369
# 130/130 [==============================] - 88s 675ms/step - loss: 0.0916 - accuracy: 0.9753 - val_loss: 0.5974 - val_accuracy: 0.8500
# Epoch 49/50
# 130/130 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9738
# Epoch 49: val_loss did not improve from 0.58369
# 130/130 [==============================] - 81s 621ms/step - loss: 0.0959 - accuracy: 0.9738 - val_loss: 0.6214 - val_accuracy: 0.8344
# Epoch 50/50
# 130/130 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9792
# Epoch 50: val_loss did not improve from 0.58369
# 130/130 [==============================] - 80s 617ms/step - loss: 0.0951 - accuracy: 0.9792 - val_loss: 0.5988 - val_accuracy: 0.8344

# %%
train_accuracy = history_mobileNet.history['accuracy']
val_accuracy = history_mobileNet.history['val_accuracy']
train_loss = history_mobileNet.history['loss']
val_loss= history_mobileNet.history['val_loss']

plt.figure(figsize=(16, 8))

# Cek hasil akurasi
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Training Accuracy', color='#185fad')
plt.plot(val_accuracy, label='Validation Accuracy', color='orange')

plt.title('Training and Validation Accuracy by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))

plt.legend(fontsize = 18);

plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss', color='#185fad')
plt.plot(val_loss, label='Validation Loss', color='orange')

plt.title('Training and Validation Loss by Epoch', fontsize = 18)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Mean-Square-Error', fontsize = 18)
plt.xticks(range(0,16,20), range(0,16,20))


plt.legend(fontsize = 18)

# %%
#Plot the confusion matrix. Set Normalize = True/False

def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(20,20))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Print the Target names
from sklearn.metrics import classification_report, confusion_matrix
import itertools 
#shuffle=False

target_names = []
for key in validasi_data.class_indices:
    target_names.append(key)

# print(target_names)

#Confution Matrix 

Y_pred = mobileNet_model.predict_generator(validasi_data)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm = confusion_matrix(validasi_data.classes, y_pred)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')

#Print Classification Report
print('Classification Report')
print(classification_report(validasi_data.classes, y_pred, target_names=target_names))
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18232\385079297.py:47: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = mobileNet_model.predict_generator(validasi_data)
# Confusion Matrix
# Normalized confusion matrix
# Classification Report
#               precision    recall  f1-score   support
#
#            a       1.00      1.00      1.00        28
#            b       0.91      0.89      0.90        36
#            c       0.97      0.97      0.97        32
#        colon       1.00      0.44      0.62         9
#            d       0.83      0.95      0.89        41
#            e       0.81      0.72      0.76        18
#            f       0.58      0.83      0.68        18
#            g       0.95      0.82      0.88        22
#            h       0.95      0.76      0.84        25
#            i       0.81      0.74      0.77        23
#            j       0.81      0.81      0.81        27
#            k       0.80      0.95      0.87        21
#         koma       1.00      0.86      0.92         7
#            l       0.94      0.81      0.87        21
#            m       0.82      0.82      0.82        17
#            n       0.93      0.74      0.82        19
#            o       1.00      0.67      0.80        24
#            p       0.68      0.87      0.76        15
#   petik_satu       1.00      0.50      0.67         6
#            q       0.48      0.94      0.64        16
#            r       0.70      0.80      0.74        20
#            s       0.95      0.95      0.95        20
#    semicolon       0.36      1.00      0.53         4
#        space       1.00      0.71      0.83         7
#            t       0.91      0.80      0.85        25
# tanda_hubung       1.00      1.00      1.00         8
#   tanda_seru       0.83      0.71      0.77         7
#  tanda_tanya       0.75      0.67      0.71         9
#        titik       1.00      0.75      0.86         8
#            u       0.86      0.86      0.86        22
#            v       0.74      0.82      0.78        17
#            w       0.85      0.85      0.85        20
#            x       0.82      0.74      0.78        19
#            y       0.90      0.95      0.92        19
#            z       0.89      0.81      0.85        21
#
#     accuracy                           0.84       651
#    macro avg       0.85      0.81      0.82       651
# weighted avg       0.86      0.84      0.84       651

# %%
# Predict the label of the test_images
from tensorflow.keras.models import load_model

# Load the trained model
mobileNet_model = load_model('MobileNet_Braille_model_best.h5')

pred = mobileNet_model.predict(validasi_data)
pred_classes = np.argmax(pred,axis=1)
pred_proba = np.max(pred, axis=1)

# Map the label
labels = (train_data.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred_classes = [labels[k] for k in pred_classes]

# Display the result
print(f'The first 15 predictions: {pred_classes[:15]}')
# Out:
# 41/41 [==============================] - 13s 233ms/step
# The first 15 predictions: ['b', 'h', 'z', 'n', 'v', 'l', 'r', 'l', 'g', 'b', 'a', 'tanda_hubung', 'b', 't', 'w']

# %%
# Display the result
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(validasi_df.Filepath.iloc[i]))
    ax.set_title(f"True: {validasi_df.Label.iloc[i]}\nPredicted: {pred_classes[i]}\nProbability: {pred_proba[i]:.3f}")
plt.tight_layout()
plt.show()
