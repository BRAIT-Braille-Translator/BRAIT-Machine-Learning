# %%
import os
import numpy as np
import pandas as pd
import shutil
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pathlib import Path
from shutil import copyfile

# %% [markdown]
# Path Control

# %%
dataset_dir = r'D:\astungkara\BrailleDataset'
train_dir = r'D:\astungkara\BrailleDataset\train'
test_dir = r'D:\astungkara\BrailleDataset\test'

# Create train and test directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# %% [markdown]
# Load Images and Labels, Plot Distribution

# %%
# Load images and labels
images = []
labels = []
classes = ['a', 'b', 'c', 'colon', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'koma', 'l', 'm', 'n', 'o', 'p', 'petik_satu', 'q', 'r', 's', 'semicolon', 'space', 't', 'tanda_hubung', 'tanda_seru', 'tanda_tanya', 'titik', 'u', 'v', 'w', 'x', 'y', 'z']

for label in classes:
    path = os.path.join(dataset_dir, label)
    for file in os.listdir(path):
        if file.endswith(".jpg"):
            images.append(os.path.join(path, file))
            labels.append(label)

# Plot the distribution of the labels
label_df = pd.DataFrame(labels, columns=['Labels'])
plt.figure(figsize=(10,5))
label_df['Labels'].value_counts().plot(kind='bar')
plt.title('Distribution of the dataset')
plt.show()

# %% [markdown]
# Split Data

# %%
# Split the data
train_images, test_images, train_labels, test_labels = train_test_split(images, labels, stratify=labels, test_size=0.2)

# Create subdirectories in train and test directories for each class
for label in ['a', 'b', 'c', 'colon', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'koma', 'l', 'm', 'n', 'o', 'p', 'petik_satu', 'q', 'r', 's', 'semicolon', 'space', 't', 'tanda_hubung', 'tanda_seru', 'tanda_tanya', 'titik', 'u', 'v', 'w', 'x', 'y', 'z']:
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(test_dir, label), exist_ok=True)

# Copy the data to the training and test folders
for i in range(len(train_images)):
    shutil.copy(train_images[i], os.path.join(train_dir, train_labels[i], os.path.basename(train_images[i])))

for i in range(len(test_images)):
    shutil.copy(test_images[i], os.path.join(test_dir, test_labels[i], os.path.basename(test_images[i])))

# %%
#a
folder_path = (r'D:\astungkara\BrailleDataset\train\a')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#b
folder_path = (r'D:\astungkara\BrailleDataset\train\b')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#c
folder_path = (r'D:\astungkara\BrailleDataset\train\c')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#colon
folder_path = (r'D:\astungkara\BrailleDataset\train\colon')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#d
folder_path = (r'D:\astungkara\BrailleDataset\train\d')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#e
folder_path = (r'D:\astungkara\BrailleDataset\train\e')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#f
folder_path = (r'D:\astungkara\BrailleDataset\train\f')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#g
folder_path = (r'D:\astungkara\BrailleDataset\train\g')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#h
folder_path = (r'D:\astungkara\BrailleDataset\train\h')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#i
folder_path = (r'D:\astungkara\BrailleDataset\train\i')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#j
folder_path = (r'D:\astungkara\BrailleDataset\train\j')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#k
folder_path = (r'D:\astungkara\BrailleDataset\train\k')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#koma
folder_path = (r'D:\astungkara\BrailleDataset\train\koma')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#l
folder_path = (r'D:\astungkara\BrailleDataset\train\l')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#m
folder_path = (r'D:\astungkara\BrailleDataset\train\m')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#n
folder_path = (r'D:\astungkara\BrailleDataset\train\n')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#o
folder_path = (r'D:\astungkara\BrailleDataset\train\o')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#p
folder_path = (r'D:\astungkara\BrailleDataset\train\p')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#petik_satu
folder_path = (r'D:\astungkara\BrailleDataset\train\petik_satu')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#q
folder_path = (r'D:\astungkara\BrailleDataset\train\q')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#r
folder_path = (r'D:\astungkara\BrailleDataset\train\r')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#s
folder_path = (r'D:\astungkara\BrailleDataset\train\s')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#semicolon
folder_path = (r'D:\astungkara\BrailleDataset\train\semicolon')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#space
folder_path = (r'D:\astungkara\BrailleDataset\train\space')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#t
folder_path = (r'D:\astungkara\BrailleDataset\train\t')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#tanda_hubung
folder_path = (r'D:\astungkara\BrailleDataset\train\tanda_hubung')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#tanda_seru
folder_path = (r'D:\astungkara\BrailleDataset\train\tanda_seru')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#tanda_tanya
folder_path = (r'D:\astungkara\BrailleDataset\train\tanda_tanya')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#titik
folder_path = (r'D:\astungkara\BrailleDataset\train\titik')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#u
folder_path = (r'D:\astungkara\BrailleDataset\train\u')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#v
folder_path = (r'D:\astungkara\BrailleDataset\train\v')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#w
folder_path = (r'D:\astungkara\BrailleDataset\train\w')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#x
folder_path = (r'D:\astungkara\BrailleDataset\train\x')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#y
folder_path = (r'D:\astungkara\BrailleDataset\train\y')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

#z
folder_path = (r'D:\astungkara\BrailleDataset\train\z')
test = os.listdir(folder_path)
for fichier in test: 
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
image_dir = Path(r'D:\astungkara\BrailleDataset\train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(2)
# Out:
#                                             Filepath Label
# 0  D:\astungkara\BrailleDataset\train\d\d_dataset...     d
# 1  D:\astungkara\BrailleDataset\train\x\x1.JPG5wh...     x

# %%
# Display some pictures of the dataset with their labels

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()
